# %%
import torch

import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact, IntSlider

from Utilities.utils import run_and_cache
from Utilities.TST_trainer import  TimeSeriesTransformer, load_dataset

# %%
torch.manual_seed(123)
np.random.seed(123)

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(DEVICE)
# Out:
# cpu

# %% [markdown]
# ## Sparse Autoencoder Definition
#
# L1 Sparsity loss

# %%
ACTIVATION_TENSOR = None

# %%
class SparseAutoencoder(nn.Module):
    def __init__(self, input_dim, hidden_dim, sparsity_lambda=1e-3):
        super(SparseAutoencoder, self).__init__()
        self.encoder = nn.Linear(input_dim, hidden_dim)
        self.decoder = nn.Linear(hidden_dim, input_dim)
        self.sparsity_lambda = sparsity_lambda

    def forward(self, x):
        h = F.relu(self.encoder(x))
        x_hat = self.decoder(h)
        return x_hat, h
    
    def loss(self, x, x_hat, h):
        reconstruction_loss = F.mse_loss(x_hat, x)
        sparsity_penalty = self.sparsity_lambda * torch.sum(torch.abs(h))
        return reconstruction_loss + sparsity_penalty

# %% [markdown]
# ## Load Pretrained Transformer Model and Dataset
#
# Loads the JapaneseVowels dataset and the pretrained Time Series Transformer (TST). Extracts the input batch and label tensors for use in downstream analysis.

# %%
MODEL_PATH = "../TST_models/TST_japanesevowels.pth"
DATASET_NAME = "JapaneseVowels"

# %%
train_loader, test_loader = load_dataset(DATASET_NAME, batch_size=4)

full_train_inputs = []
full_train_labels = []
for x, y in train_loader:
    full_train_inputs.append(x)
    full_train_labels.append(y)

train_batch = torch.cat(full_train_inputs).to(DEVICE)  # (N, seq_len, channels)
label_batch = torch.cat(full_train_labels)             # (N,)

train_labels = label_batch
seq_len, channels = train_batch.shape[1], train_batch.shape[2]
num_classes = int(train_labels.max().item()) + 1

model = TimeSeriesTransformer(
    input_dim=channels,
    num_classes=num_classes,
    seq_len=seq_len
)

model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
model = model.to(DEVICE).eval()
# Out:
# C:\Users\matis\AppData\Local\Temp\ipykernel_16056\391293175.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))

# %% [markdown]
# ## Inspect Transformer Layers

# %%
for name, module in model.named_modules():
    print(name)
# Out:
# conv1
# bn1
# conv2
# bn2
# conv3
# bn3
# transformer_encoder
# transformer_encoder.layers
# transformer_encoder.layers.0
# transformer_encoder.layers.0.self_attn
# transformer_encoder.layers.0.self_attn.out_proj
# transformer_encoder.layers.0.linear1
# transformer_encoder.layers.0.dropout
# transformer_encoder.layers.0.linear2
# transformer_encoder.layers.0.norm1
# transformer_encoder.layers.0.norm2
# transformer_encoder.layers.0.dropout1
# transformer_encoder.layers.0.dropout2
# transformer_encoder.layers.1
# transformer_encoder.layers.1.self_attn
# transformer_encoder.layers.1.self_attn.out_proj
# transformer_encoder.layers.1.linear1
# transformer_encoder.layers.1.dropout
# transformer_encoder.layers.1.linear2
# transformer_encoder.layers.1.norm1
# transformer_encoder.layers.1.norm2
# transformer_encoder.layers.1.dropout1
# transformer_encoder.layers.1.dropout2
# transformer_encoder.layers.2
# transformer_encoder.layers.2.self_attn
# transformer_encoder.layers.2.self_attn.out_proj
# transformer_encoder.layers.2.linear1
# transformer_encoder.layers.2.dropout
# transformer_encoder.layers.2.linear2
# transformer_encoder.layers.2.norm1
# transformer_encoder.layers.2.norm2
# transformer_encoder.layers.2.dropout1
# transformer_encoder.layers.2.dropout2
# pool
# classifier

# %% [markdown]
# ## Select Target Layer for Activation Extraction

# %%
LAYER_TARGETS = ["transformer_encoder.layers.0.linear2"]

# %% [markdown]
# ## Extract Activations from Transformer (Train Set)

# %%
cache = run_and_cache(model, train_batch, targets=LAYER_TARGETS)
activations = list(cache.values())[0]
ACTIVATION_TENSOR = activations.view(-1, activations.size(-1)).cpu()
total_timesteps, feature_dim = ACTIVATION_TENSOR.shape

# we know each instance is seq_len long
seq_len = train_batch.shape[1]

# compute how many instances we have
num_instances = total_timesteps // seq_len
assert num_instances * seq_len == total_timesteps, \
       "timesteps not divisible by seq_len!"

# now reshape
sequences = ACTIVATION_TENSOR.view(num_instances, seq_len, feature_dim)  # (num_instances, seq_len, feature_dim)
labels = train_labels  # shape (num_instances,)

# %%
dataset = TensorDataset(sequences, labels)
loader  = DataLoader(dataset, batch_size=8, shuffle=True)

# %% [markdown]
# # Training the Model below! Don't run if don't want to!

# %%
hidden_dim = 128
sparsity_lambda = 1e-4


sae    = SparseAutoencoder(feature_dim, hidden_dim, sparsity_lambda).to(DEVICE)
opt    = torch.optim.Adam(sae.parameters(), lr=1e-3)
epochs = 1000

for epoch in range(epochs):
    sae.train()
    total_loss = 0.
    for seq_batch, _ in loader:
        x = seq_batch.view(-1, feature_dim).to(DEVICE)   # flatten timesteps
        x_hat, h = sae(x)
        l = sae.loss(x, x_hat, h)

        opt.zero_grad()
        l.backward()
        opt.step()

        total_loss += l.item() * x.size(0)
    print(f"Epoch {epoch:3d} — Loss: {total_loss/len(loader.dataset):.4f}")
    
torch.save(sae.state_dict(), "SAE_models/sae_enc0lin2.pth")
# Out:
# Epoch   0 — Loss: 12.5008
# Epoch   1 — Loss: 9.7577
# Epoch   2 — Loss: 7.9108
# Epoch   3 — Loss: 6.6271
# Epoch   4 — Loss: 5.8743
# Epoch   5 — Loss: 5.3440
# Epoch   6 — Loss: 4.9449
# Epoch   7 — Loss: 4.6770
# Epoch   8 — Loss: 4.4569
# Epoch   9 — Loss: 4.2870
# Epoch  10 — Loss: 4.1362
# Epoch  11 — Loss: 4.0010
# Epoch  12 — Loss: 3.8904
# Epoch  13 — Loss: 3.7904
# Epoch  14 — Loss: 3.7007
# Epoch  15 — Loss: 3.6260
# Epoch  16 — Loss: 3.5499
# Epoch  17 — Loss: 3.4812
# Epoch  18 — Loss: 3.4151
# Epoch  19 — Loss: 3.3489
# Epoch  20 — Loss: 3.2908
# Epoch  21 — Loss: 3.2260
# Epoch  22 — Loss: 3.1655
# Epoch  23 — Loss: 3.1009
# Epoch  24 — Loss: 3.0521
# Epoch  25 — Loss: 3.0017
# Epoch  26 — Loss: 2.9529
# Epoch  27 — Loss: 2.9129
# Epoch  28 — Loss: 2.8735
# Epoch  29 — Loss: 2.8341
# Epoch  30 — Loss: 2.8043
# Epoch  31 — Loss: 2.7726
# Epoch  32 — Loss: 2.7473
# Epoch  33 — Loss: 2.7130
# Epoch  34 — Loss: 2.6885
# Epoch  35 — Loss: 2.6665
# Epoch  36 — Loss: 2.6451
# Epoch  37 — Loss: 2.6237
# Epoch  38 — Loss: 2.5959
# Epoch  39 — Loss: 2.5756
# Epoch  40 — Loss: 2.5562
# Epoch  41 — Loss: 2.5434
# Epoch  42 — Loss: 2.5179
# Epoch  43 — Loss: 2.5001
# Epoch  44 — Loss: 2.4820
# Epoch  45 — Loss: 2.4778
# Epoch  46 — Loss: 2.4512
# Epoch  47 — Loss: 2.4340
# Epoch  48 — Loss: 2.4215
# Epoch  49 — Loss: 2.3983
# Epoch  50 — Loss: 2.3834
# Epoch  51 — Loss: 2.3744
# Epoch  52 — Loss: 2.3570
# Epoch  53 — Loss: 2.3461
# Epoch  54 — Loss: 2.3290
# Epoch  55 — Loss: 2.3150
# Epoch  56 — Loss: 2.3043
# Epoch  57 — Loss: 2.2960
# Epoch  58 — Loss: 2.2837
# Epoch  59 — Loss: 2.2725
# Epoch  60 — Loss: 2.2572
# Epoch  61 — Loss: 2.2448
# Epoch  62 — Loss: 2.2287
# Epoch  63 — Loss: 2.2184
# Epoch  64 — Loss: 2.2083
# Epoch  65 — Loss: 2.2255
# Epoch  66 — Loss: 2.2046
# Epoch  67 — Loss: 2.1741
# Epoch  68 — Loss: 2.1688
# Epoch  69 — Loss: 2.1605
# Epoch  70 — Loss: 2.1518
# Epoch  71 — Loss: 2.1525
# Epoch  72 — Loss: 2.1297
# Epoch  73 — Loss: 2.1241
# Epoch  74 — Loss: 2.1121
# Epoch  75 — Loss: 2.1026
# Epoch  76 — Loss: 2.1008
# Epoch  77 — Loss: 2.0863
# Epoch  78 — Loss: 2.0842
# Epoch  79 — Loss: 2.0669
# Epoch  80 — Loss: 2.0556
# Epoch  81 — Loss: 2.0515
# Epoch  82 — Loss: 2.0489
# Epoch  83 — Loss: 2.0364
# Epoch  84 — Loss: 2.0277
# Epoch  85 — Loss: 2.0205
# Epoch  86 — Loss: 2.0086
# Epoch  87 — Loss: 2.0281
# Epoch  88 — Loss: 2.1104
# Epoch  89 — Loss: 2.0265
# Epoch  90 — Loss: 1.9902
# Epoch  91 — Loss: 1.9788
# Epoch  92 — Loss: 1.9770
# Epoch  93 — Loss: 1.9808
# Epoch  94 — Loss: 1.9614
# Epoch  95 — Loss: 1.9516
# Epoch  96 — Loss: 1.9422
# Epoch  97 — Loss: 1.9568
# Epoch  98 — Loss: 1.9459
# Epoch  99 — Loss: 1.9245
# Epoch 100 — Loss: 1.9164
# Epoch 101 — Loss: 1.9134
# Epoch 102 — Loss: 1.9067
# Epoch 103 — Loss: 1.8982
# Epoch 104 — Loss: 1.9097
# Epoch 105 — Loss: 1.9019
# Epoch 106 — Loss: 1.8863
# Epoch 107 — Loss: 1.8777
# Epoch 108 — Loss: 1.8900
# Epoch 109 — Loss: 1.9016
# Epoch 110 — Loss: 1.8725
# Epoch 111 — Loss: 1.8717
# Epoch 112 — Loss: 1.8542
# Epoch 113 — Loss: 1.8613
# Epoch 114 — Loss: 1.8437
# Epoch 115 — Loss: 1.8322
# Epoch 116 — Loss: 1.8325
# Epoch 117 — Loss: 1.8285
# Epoch 118 — Loss: 1.8219
# Epoch 119 — Loss: 1.8165
# Epoch 120 — Loss: 1.8159
# Epoch 121 — Loss: 1.8122
# Epoch 122 — Loss: 1.8111
# Epoch 123 — Loss: 1.8048
# Epoch 124 — Loss: 1.8518
# Epoch 125 — Loss: 1.8569
# Epoch 126 — Loss: 1.8089
# Epoch 127 — Loss: 1.8245
# Epoch 128 — Loss: 1.8407
# Epoch 129 — Loss: 1.8067
# Epoch 130 — Loss: 1.7726
# Epoch 131 — Loss: 1.7639
# Epoch 132 — Loss: 1.7642
# Epoch 133 — Loss: 1.7661
# Epoch 134 — Loss: 1.7625
# Epoch 135 — Loss: 1.7506
# Epoch 136 — Loss: 1.7489
# Epoch 137 — Loss: 1.7538
# Epoch 138 — Loss: 1.7435
# Epoch 139 — Loss: 1.7456
# Epoch 140 — Loss: 1.7429
# Epoch 141 — Loss: 1.7352
# Epoch 142 — Loss: 1.7324
# Epoch 143 — Loss: 1.7194
# Epoch 144 — Loss: 1.7150
# Epoch 145 — Loss: 1.7241
# Epoch 146 — Loss: 1.7254
# Epoch 147 — Loss: 1.7421
# Epoch 148 — Loss: 1.7160
# Epoch 149 — Loss: 1.7016
# Epoch 150 — Loss: 1.7173
# Epoch 151 — Loss: 1.7095
# Epoch 152 — Loss: 1.7094
# Epoch 153 — Loss: 1.6922
# Epoch 154 — Loss: 1.6780
# Epoch 155 — Loss: 1.6710
# Epoch 156 — Loss: 1.6684
# Epoch 157 — Loss: 1.6705
# Epoch 158 — Loss: 1.6746
# Epoch 159 — Loss: 1.6693
# Epoch 160 — Loss: 1.6730
# Epoch 161 — Loss: 1.7236
# Epoch 162 — Loss: 1.7073
# Epoch 163 — Loss: 1.6882
# Epoch 164 — Loss: 1.6585
# Epoch 165 — Loss: 1.6470
# Epoch 166 — Loss: 1.6591
# Epoch 167 — Loss: 1.6550
# Epoch 168 — Loss: 1.6634
# Epoch 169 — Loss: 1.6608
# Epoch 170 — Loss: 1.6500
# Epoch 171 — Loss: 1.6420
# Epoch 172 — Loss: 1.6356
# Epoch 173 — Loss: 1.6510
# Epoch 174 — Loss: 1.6434
# Epoch 175 — Loss: 1.6844
# Epoch 176 — Loss: 1.6633
# Epoch 177 — Loss: 1.6796
# Epoch 178 — Loss: 1.6293
# Epoch 179 — Loss: 1.6079
# Epoch 180 — Loss: 1.6116
# Epoch 181 — Loss: 1.6070
# Epoch 182 — Loss: 1.6006
# Epoch 183 — Loss: 1.6027
# Epoch 184 — Loss: 1.6145
# Epoch 185 — Loss: 1.6015
# Epoch 186 — Loss: 1.5978
# Epoch 187 — Loss: 1.5831
# Epoch 188 — Loss: 1.5795
# Epoch 189 — Loss: 1.5769
# Epoch 190 — Loss: 1.5965
# Epoch 191 — Loss: 1.5964
# Epoch 192 — Loss: 1.6178
# Epoch 193 — Loss: 1.6135
# Epoch 194 — Loss: 1.6401
# Epoch 195 — Loss: 1.6101
# Epoch 196 — Loss: 1.5797
# Epoch 197 — Loss: 1.5712
# Epoch 198 — Loss: 1.5609
# Epoch 199 — Loss: 1.5539
# Epoch 200 — Loss: 1.5509
# Epoch 201 — Loss: 1.5554
# Epoch 202 — Loss: 1.6095
# Epoch 203 — Loss: 1.6192
# Epoch 204 — Loss: 1.5846
# Epoch 205 — Loss: 1.5529
# Epoch 206 — Loss: 1.5406
# Epoch 207 — Loss: 1.5389
# Epoch 208 — Loss: 1.5501
# Epoch 209 — Loss: 1.5513
# Epoch 210 — Loss: 1.5389
# Epoch 211 — Loss: 1.5844
# Epoch 212 — Loss: 1.5759
# Epoch 213 — Loss: 1.5549
# Epoch 214 — Loss: 1.5293
# Epoch 215 — Loss: 1.5505
# Epoch 216 — Loss: 1.5538
# Epoch 217 — Loss: 1.6103
# Epoch 218 — Loss: 1.5769
# Epoch 219 — Loss: 1.5470
# Epoch 220 — Loss: 1.5422
# Epoch 221 — Loss: 1.5704
# Epoch 222 — Loss: 1.5233
# Epoch 223 — Loss: 1.5080
# Epoch 224 — Loss: 1.5007
# Epoch 225 — Loss: 1.5042
# Epoch 226 — Loss: 1.5533
# Epoch 227 — Loss: 1.5979
# Epoch 228 — Loss: 1.5584
# Epoch 229 — Loss: 1.5062
# Epoch 230 — Loss: 1.4931
# Epoch 231 — Loss: 1.4912
# Epoch 232 — Loss: 1.4910
# Epoch 233 — Loss: 1.5244
# Epoch 234 — Loss: 1.5000
# Epoch 235 — Loss: 1.4932
# Epoch 236 — Loss: 1.5080
# Epoch 237 — Loss: 1.5078
# Epoch 238 — Loss: 1.4830
# Epoch 239 — Loss: 1.4870
# Epoch 240 — Loss: 1.5145
# Epoch 241 — Loss: 1.5015
# Epoch 242 — Loss: 1.4950
# Epoch 243 — Loss: 1.5233
# Epoch 244 — Loss: 1.5174
# Epoch 245 — Loss: 1.5307
# Epoch 246 — Loss: 1.5451
# Epoch 247 — Loss: 1.4935
# Epoch 248 — Loss: 1.4720
# Epoch 249 — Loss: 1.4737
# Epoch 250 — Loss: 1.4721
# Epoch 251 — Loss: 1.4940
# Epoch 252 — Loss: 1.5142
# Epoch 253 — Loss: 1.4982
# Epoch 254 — Loss: 1.4901
# Epoch 255 — Loss: 1.4809
# Epoch 256 — Loss: 1.4952
# Epoch 257 — Loss: 1.5303
# Epoch 258 — Loss: 1.4872
# Epoch 259 — Loss: 1.4801
# Epoch 260 — Loss: 1.4658
# Epoch 261 — Loss: 1.4640
# Epoch 262 — Loss: 1.4546
# Epoch 263 — Loss: 1.4540
# Epoch 264 — Loss: 1.5143
# Epoch 265 — Loss: 1.5516
# Epoch 266 — Loss: 1.5622
# Epoch 267 — Loss: 1.5099
# Epoch 268 — Loss: 1.4831
# Epoch 269 — Loss: 1.4952
# Epoch 270 — Loss: 1.4616
# Epoch 271 — Loss: 1.5254
# Epoch 272 — Loss: 1.4815
# Epoch 273 — Loss: 1.4802
# Epoch 274 — Loss: 1.5024
# Epoch 275 — Loss: 1.4754
# Epoch 276 — Loss: 1.4466
# Epoch 277 — Loss: 1.4381
# Epoch 278 — Loss: 1.4515
# Epoch 279 — Loss: 1.4788
# Epoch 280 — Loss: 1.5896
# Epoch 281 — Loss: 1.5163
# Epoch 282 — Loss: 1.4472
# Epoch 283 — Loss: 1.4323
# Epoch 284 — Loss: 1.4336
# Epoch 285 — Loss: 1.4867
# Epoch 286 — Loss: 1.4942
# Epoch 287 — Loss: 1.4378
# Epoch 288 — Loss: 1.4198
# Epoch 289 — Loss: 1.4171
# Epoch 290 — Loss: 1.4307
# Epoch 291 — Loss: 1.4876
# Epoch 292 — Loss: 1.4691
# Epoch 293 — Loss: 1.4269
# Epoch 294 — Loss: 1.4146
# Epoch 295 — Loss: 1.4122
# Epoch 296 — Loss: 1.4289
# Epoch 297 — Loss: 1.4354
# Epoch 298 — Loss: 1.4400
# Epoch 299 — Loss: 1.4550
# Epoch 300 — Loss: 1.4467
# Epoch 301 — Loss: 1.4333
# Epoch 302 — Loss: 1.4228
# Epoch 303 — Loss: 1.4222
# Epoch 304 — Loss: 1.4476
# Epoch 305 — Loss: 1.4253
# Epoch 306 — Loss: 1.4289
# Epoch 307 — Loss: 1.4560
# Epoch 308 — Loss: 1.4067
# Epoch 309 — Loss: 1.3894
# Epoch 310 — Loss: 1.3889
# Epoch 311 — Loss: 1.4026
# Epoch 312 — Loss: 1.4308
# Epoch 313 — Loss: 1.4237
# Epoch 314 — Loss: 1.4575
# Epoch 315 — Loss: 1.5081
# Epoch 316 — Loss: 1.4901
# Epoch 317 — Loss: 1.4862
# Epoch 318 — Loss: 1.4588
# Epoch 319 — Loss: 1.4030
# Epoch 320 — Loss: 1.3934
# Epoch 321 — Loss: 1.4636
# Epoch 322 — Loss: 1.4421
# Epoch 323 — Loss: 1.4377
# Epoch 324 — Loss: 1.4885
# Epoch 325 — Loss: 1.4542
# Epoch 326 — Loss: 1.4006
# Epoch 327 — Loss: 1.3896
# Epoch 328 — Loss: 1.3774
# Epoch 329 — Loss: 1.5072
# Epoch 330 — Loss: 1.5933
# Epoch 331 — Loss: 1.5411
# Epoch 332 — Loss: 1.4682
# Epoch 333 — Loss: 1.4187
# Epoch 334 — Loss: 1.4522
# Epoch 335 — Loss: 1.3943
# Epoch 336 — Loss: 1.3946
# Epoch 337 — Loss: 1.4129
# Epoch 338 — Loss: 1.3745
# Epoch 339 — Loss: 1.3808
# Epoch 340 — Loss: 1.3854
# Epoch 341 — Loss: 1.4228
# Epoch 342 — Loss: 1.3933
# Epoch 343 — Loss: 1.4233
# Epoch 344 — Loss: 1.4057
# Epoch 345 — Loss: 1.3919
# Epoch 346 — Loss: 1.3804
# Epoch 347 — Loss: 1.3948
# Epoch 348 — Loss: 1.3910
# Epoch 349 — Loss: 1.3648
# Epoch 350 — Loss: 1.3550
# Epoch 351 — Loss: 1.3640
# Epoch 352 — Loss: 1.3587
# Epoch 353 — Loss: 1.3842
# Epoch 354 — Loss: 1.4561
# Epoch 355 — Loss: 1.5581
# Epoch 356 — Loss: 1.4179
# Epoch 357 — Loss: 1.3748
# Epoch 358 — Loss: 1.4942
# Epoch 359 — Loss: 1.4957
# Epoch 360 — Loss: 1.4203
# Epoch 361 — Loss: 1.3903
# Epoch 362 — Loss: 1.3698
# Epoch 363 — Loss: 1.4008
# Epoch 364 — Loss: 1.4765
# Epoch 365 — Loss: 1.4040
# Epoch 366 — Loss: 1.3938
# Epoch 367 — Loss: 1.4324
# Epoch 368 — Loss: 1.4463
# Epoch 369 — Loss: 1.4175
# Epoch 370 — Loss: 1.3825
# Epoch 371 — Loss: 1.4082
# Epoch 372 — Loss: 1.4321
# Epoch 373 — Loss: 1.3843
# Epoch 374 — Loss: 1.3618
# Epoch 375 — Loss: 1.3903
# Epoch 376 — Loss: 1.4009
# Epoch 377 — Loss: 1.3955
# Epoch 378 — Loss: 1.3899
# Epoch 379 — Loss: 1.3575
# Epoch 380 — Loss: 1.3717
# Epoch 381 — Loss: 1.3700
# Epoch 382 — Loss: 1.4164
# Epoch 383 — Loss: 1.3926
# Epoch 384 — Loss: 1.3756
# Epoch 385 — Loss: 1.3621
# Epoch 386 — Loss: 1.3507
# Epoch 387 — Loss: 1.3503
# Epoch 388 — Loss: 1.3568
# Epoch 389 — Loss: 1.3594
# Epoch 390 — Loss: 1.3537
# Epoch 391 — Loss: 1.3639
# Epoch 392 — Loss: 1.3601
# Epoch 393 — Loss: 1.3420
# Epoch 394 — Loss: 1.3494
# Epoch 395 — Loss: 1.3688
# Epoch 396 — Loss: 1.3547
# Epoch 397 — Loss: 1.3886
# Epoch 398 — Loss: 1.3831
# Epoch 399 — Loss: 1.3924
# Epoch 400 — Loss: 1.3610
# Epoch 401 — Loss: 1.4069
# Epoch 402 — Loss: 1.4637
# Epoch 403 — Loss: 1.3820
# Epoch 404 — Loss: 1.3799
# Epoch 405 — Loss: 1.3800
# Epoch 406 — Loss: 1.4710
# Epoch 407 — Loss: 1.5707
# Epoch 408 — Loss: 1.4052
# Epoch 409 — Loss: 1.3412
# Epoch 410 — Loss: 1.3284
# Epoch 411 — Loss: 1.3407
# Epoch 412 — Loss: 1.3564
# Epoch 413 — Loss: 1.3399
# Epoch 414 — Loss: 1.3508
# Epoch 415 — Loss: 1.3606
# Epoch 416 — Loss: 1.4159
# Epoch 417 — Loss: 1.4435
# Epoch 418 — Loss: 1.5690
# Epoch 419 — Loss: 1.4032
# Epoch 420 — Loss: 1.4430
# Epoch 421 — Loss: 1.3912
# Epoch 422 — Loss: 1.4167
# Epoch 423 — Loss: 1.4590
# Epoch 424 — Loss: 1.3633
# Epoch 425 — Loss: 1.3661
# Epoch 426 — Loss: 1.3741
# Epoch 427 — Loss: 1.3808
# Epoch 428 — Loss: 1.3646
# Epoch 429 — Loss: 1.3908
# Epoch 430 — Loss: 1.3492
# Epoch 431 — Loss: 1.3162
# Epoch 432 — Loss: 1.3087
# Epoch 433 — Loss: 1.3118
# Epoch 434 — Loss: 1.3083
# Epoch 435 — Loss: 1.3099
# Epoch 436 — Loss: 1.3279
# Epoch 437 — Loss: 1.4450
# Epoch 438 — Loss: 1.3933
# Epoch 439 — Loss: 1.3410
# Epoch 440 — Loss: 1.3689
# Epoch 441 — Loss: 1.3889
# Epoch 442 — Loss: 1.3980
# Epoch 443 — Loss: 1.4708
# Epoch 444 — Loss: 1.4779
# Epoch 445 — Loss: 1.5164
# Epoch 446 — Loss: 1.6056
# Epoch 447 — Loss: 1.5300
# Epoch 448 — Loss: 1.4149
# Epoch 449 — Loss: 1.4217
# Epoch 450 — Loss: 1.3520
# Epoch 451 — Loss: 1.3336
# Epoch 452 — Loss: 1.4174
# Epoch 453 — Loss: 1.4242
# Epoch 454 — Loss: 1.3464
# Epoch 455 — Loss: 1.3124
# Epoch 456 — Loss: 1.3038
# Epoch 457 — Loss: 1.2986
# Epoch 458 — Loss: 1.3029
# Epoch 459 — Loss: 1.3239
# Epoch 460 — Loss: 1.3468
# Epoch 461 — Loss: 1.3536
# Epoch 462 — Loss: 1.3257
# Epoch 463 — Loss: 1.3098
# Epoch 464 — Loss: 1.3237
# Epoch 465 — Loss: 1.3381
# Epoch 466 — Loss: 1.3858
# Epoch 467 — Loss: 1.3588
# Epoch 468 — Loss: 1.3292
# Epoch 469 — Loss: 1.3340
# Epoch 470 — Loss: 1.5373
# Epoch 471 — Loss: 1.6029
# Epoch 472 — Loss: 1.3595
# Epoch 473 — Loss: 1.3541
# Epoch 474 — Loss: 1.3979
# Epoch 475 — Loss: 1.4582
# Epoch 476 — Loss: 1.4482
# Epoch 477 — Loss: 1.3564
# Epoch 478 — Loss: 1.3417
# Epoch 479 — Loss: 1.3436
# Epoch 480 — Loss: 1.3423
# Epoch 481 — Loss: 1.4302
# Epoch 482 — Loss: 1.3638
# Epoch 483 — Loss: 1.3108
# Epoch 484 — Loss: 1.3186
# Epoch 485 — Loss: 1.3402
# Epoch 486 — Loss: 1.3386
# Epoch 487 — Loss: 1.3337
# Epoch 488 — Loss: 1.3177
# Epoch 489 — Loss: 1.3548
# Epoch 490 — Loss: 1.3779
# Epoch 491 — Loss: 1.4790
# Epoch 492 — Loss: 1.4446
# Epoch 493 — Loss: 1.4373
# Epoch 494 — Loss: 1.4043
# Epoch 495 — Loss: 1.3602
# Epoch 496 — Loss: 1.3505
# Epoch 497 — Loss: 1.3373
# Epoch 498 — Loss: 1.3628
# Epoch 499 — Loss: 1.3526
# Epoch 500 — Loss: 1.3841
# Epoch 501 — Loss: 1.4327
# Epoch 502 — Loss: 1.3924
# Epoch 503 — Loss: 1.3276
# Epoch 504 — Loss: 1.2951
# Epoch 505 — Loss: 1.2868
# Epoch 506 — Loss: 1.3019
# Epoch 507 — Loss: 1.3497
# Epoch 508 — Loss: 1.3742
# Epoch 509 — Loss: 1.7312
# Epoch 510 — Loss: 1.7067
# Epoch 511 — Loss: 1.4538
# Epoch 512 — Loss: 1.3632
# Epoch 513 — Loss: 1.3298
# Epoch 514 — Loss: 1.3444
# Epoch 515 — Loss: 1.4115
# Epoch 516 — Loss: 1.3230
# Epoch 517 — Loss: 1.2989
# Epoch 518 — Loss: 1.3332
# Epoch 519 — Loss: 1.3045
# Epoch 520 — Loss: 1.4939
# Epoch 521 — Loss: 1.5345
# Epoch 522 — Loss: 1.3989
# Epoch 523 — Loss: 1.3460
# Epoch 524 — Loss: 1.3507
# Epoch 525 — Loss: 1.3184
# Epoch 526 — Loss: 1.2833
# Epoch 527 — Loss: 1.2770
# Epoch 528 — Loss: 1.2765
# Epoch 529 — Loss: 1.2817
# Epoch 530 — Loss: 1.3171
# Epoch 531 — Loss: 1.3030
# Epoch 532 — Loss: 1.2940
# Epoch 533 — Loss: 1.2896
# Epoch 534 — Loss: 1.3038
# Epoch 535 — Loss: 1.4773
# Epoch 536 — Loss: 1.4817
# Epoch 537 — Loss: 1.3626
# Epoch 538 — Loss: 1.3073
# Epoch 539 — Loss: 1.2918
# Epoch 540 — Loss: 1.3317
# Epoch 541 — Loss: 1.4087
# Epoch 542 — Loss: 1.4382
# Epoch 543 — Loss: 1.3267
# Epoch 544 — Loss: 1.3686
# Epoch 545 — Loss: 1.4574
# Epoch 546 — Loss: 1.5539
# Epoch 547 — Loss: 1.3784
# Epoch 548 — Loss: 1.5332
# Epoch 549 — Loss: 1.4402
# Epoch 550 — Loss: 1.3332
# Epoch 551 — Loss: 1.3074
# Epoch 552 — Loss: 1.3033
# Epoch 553 — Loss: 1.2967
# Epoch 554 — Loss: 1.2987
# Epoch 555 — Loss: 1.3185
# Epoch 556 — Loss: 1.2877
# Epoch 557 — Loss: 1.2776
# Epoch 558 — Loss: 1.2753
# Epoch 559 — Loss: 1.3024
# Epoch 560 — Loss: 1.3909
# Epoch 561 — Loss: 1.4407
# Epoch 562 — Loss: 1.3679
# Epoch 563 — Loss: 1.2884
# Epoch 564 — Loss: 1.2991
# Epoch 565 — Loss: 1.2973
# Epoch 566 — Loss: 1.3406
# Epoch 567 — Loss: 1.3184
# Epoch 568 — Loss: 1.3790
# Epoch 569 — Loss: 1.6035
# Epoch 570 — Loss: 1.4397
# Epoch 571 — Loss: 1.3988
# Epoch 572 — Loss: 1.3603
# Epoch 573 — Loss: 1.4215
# Epoch 574 — Loss: 1.4148
# Epoch 575 — Loss: 1.3396
# Epoch 576 — Loss: 1.3127
# Epoch 577 — Loss: 1.2983
# Epoch 578 — Loss: 1.3572
# Epoch 579 — Loss: 1.3574
# Epoch 580 — Loss: 1.3340
# Epoch 581 — Loss: 1.3437
# Epoch 582 — Loss: 1.3199
# Epoch 583 — Loss: 1.2940
# Epoch 584 — Loss: 1.2845
# Epoch 585 — Loss: 1.2811
# Epoch 586 — Loss: 1.2997
# Epoch 587 — Loss: 1.3313
# Epoch 588 — Loss: 1.3210
# Epoch 589 — Loss: 1.3622
# Epoch 590 — Loss: 1.3959
# Epoch 591 — Loss: 1.3840
# Epoch 592 — Loss: 1.3442
# Epoch 593 — Loss: 1.2846
# Epoch 594 — Loss: 1.3003
# Epoch 595 — Loss: 1.3397
# Epoch 596 — Loss: 1.4272
# Epoch 597 — Loss: 1.3282
# Epoch 598 — Loss: 1.3007
# Epoch 599 — Loss: 1.2813
# Epoch 600 — Loss: 1.2724
# Epoch 601 — Loss: 1.3022
# Epoch 602 — Loss: 1.3131
# Epoch 603 — Loss: 1.3191
# Epoch 604 — Loss: 1.2952
# Epoch 605 — Loss: 1.2751
# Epoch 606 — Loss: 1.2787
# Epoch 607 — Loss: 1.2918
# Epoch 608 — Loss: 1.4533
# Epoch 609 — Loss: 1.4867
# Epoch 610 — Loss: 1.3785
# Epoch 611 — Loss: 1.4060
# Epoch 612 — Loss: 1.3734
# Epoch 613 — Loss: 1.3644
# Epoch 614 — Loss: 1.7298
# Epoch 615 — Loss: 1.6632
# Epoch 616 — Loss: 1.4636
# Epoch 617 — Loss: 1.4334
# Epoch 618 — Loss: 1.3251
# Epoch 619 — Loss: 1.2900
# Epoch 620 — Loss: 1.2915
# Epoch 621 — Loss: 1.2770
# Epoch 622 — Loss: 1.3093
# Epoch 623 — Loss: 1.3025
# Epoch 624 — Loss: 1.3356
# Epoch 625 — Loss: 1.3534
# Epoch 626 — Loss: 1.3439
# Epoch 627 — Loss: 1.3283
# Epoch 628 — Loss: 1.4012
# Epoch 629 — Loss: 1.4033
# Epoch 630 — Loss: 1.3906
# Epoch 631 — Loss: 1.3565
# Epoch 632 — Loss: 1.5707
# Epoch 633 — Loss: 1.5062
# Epoch 634 — Loss: 1.3437
# Epoch 635 — Loss: 1.2895
# Epoch 636 — Loss: 1.2751
# Epoch 637 — Loss: 1.3365
# Epoch 638 — Loss: 1.2737
# Epoch 639 — Loss: 1.2770
# Epoch 640 — Loss: 1.2912
# Epoch 641 — Loss: 1.3540
# Epoch 642 — Loss: 1.3436
# Epoch 643 — Loss: 1.3832
# Epoch 644 — Loss: 1.3038
# Epoch 645 — Loss: 1.3122
# Epoch 646 — Loss: 1.3688
# Epoch 647 — Loss: 1.5963
# Epoch 648 — Loss: 1.6770
# Epoch 649 — Loss: 1.3897
# Epoch 650 — Loss: 1.3603
# Epoch 651 — Loss: 1.4329
# Epoch 652 — Loss: 1.4580
# Epoch 653 — Loss: 1.3234
# Epoch 654 — Loss: 1.3088
# Epoch 655 — Loss: 1.3379
# Epoch 656 — Loss: 1.2818
# Epoch 657 — Loss: 1.2677
# Epoch 658 — Loss: 1.2724
# Epoch 659 — Loss: 1.2829
# Epoch 660 — Loss: 1.3077
# Epoch 661 — Loss: 1.3528
# Epoch 662 — Loss: 1.4343
# Epoch 663 — Loss: 1.3964
# Epoch 664 — Loss: 1.3475
# Epoch 665 — Loss: 1.3055
# Epoch 666 — Loss: 1.2940
# Epoch 667 — Loss: 1.3389
# Epoch 668 — Loss: 1.3540
# Epoch 669 — Loss: 1.2979
# Epoch 670 — Loss: 1.3201
# Epoch 671 — Loss: 1.3090
# Epoch 672 — Loss: 1.3464
# Epoch 673 — Loss: 1.3099
# Epoch 674 — Loss: 1.3115
# Epoch 675 — Loss: 1.3015
# Epoch 676 — Loss: 1.2860
# Epoch 677 — Loss: 1.3029
# Epoch 678 — Loss: 1.2923
# Epoch 679 — Loss: 1.3103
# Epoch 680 — Loss: 1.2869
# Epoch 681 — Loss: 1.3887
# Epoch 682 — Loss: 1.3425
# Epoch 683 — Loss: 1.4558
# Epoch 684 — Loss: 1.3343
# Epoch 685 — Loss: 1.3406
# Epoch 686 — Loss: 1.3203
# Epoch 687 — Loss: 1.2993
# Epoch 688 — Loss: 1.2924
# Epoch 689 — Loss: 1.3019
# Epoch 690 — Loss: 1.3042
# Epoch 691 — Loss: 1.2934
# Epoch 692 — Loss: 1.2896
# Epoch 693 — Loss: 1.3548
# Epoch 694 — Loss: 1.3993
# Epoch 695 — Loss: 1.4910
# Epoch 696 — Loss: 1.6738
# Epoch 697 — Loss: 1.5484
# Epoch 698 — Loss: 1.3299
# Epoch 699 — Loss: 1.3472
# Epoch 700 — Loss: 1.4255
# Epoch 701 — Loss: 1.3639
# Epoch 702 — Loss: 1.2815
# Epoch 703 — Loss: 1.2661
# Epoch 704 — Loss: 1.2734
# Epoch 705 — Loss: 1.3256
# Epoch 706 — Loss: 1.3338
# Epoch 707 — Loss: 1.3109
# Epoch 708 — Loss: 1.3055
# Epoch 709 — Loss: 1.2912
# Epoch 710 — Loss: 1.2865
# Epoch 711 — Loss: 1.3816
# Epoch 712 — Loss: 1.3224
# Epoch 713 — Loss: 1.2912
# Epoch 714 — Loss: 1.2777
# Epoch 715 — Loss: 1.3485
# Epoch 716 — Loss: 1.4312
# Epoch 717 — Loss: 1.3794
# Epoch 718 — Loss: 1.3137
# Epoch 719 — Loss: 1.2936
# Epoch 720 — Loss: 1.3019
# Epoch 721 — Loss: 1.4067
# Epoch 722 — Loss: 1.4040
# Epoch 723 — Loss: 1.3837
# Epoch 724 — Loss: 1.3580
# Epoch 725 — Loss: 1.3207
# Epoch 726 — Loss: 1.2844
# Epoch 727 — Loss: 1.2516
# Epoch 728 — Loss: 1.2572
# Epoch 729 — Loss: 1.4428
# Epoch 730 — Loss: 1.9856
# Epoch 731 — Loss: 1.5886
# Epoch 732 — Loss: 1.5740
# Epoch 733 — Loss: 1.4999
# Epoch 734 — Loss: 1.4025
# Epoch 735 — Loss: 1.3562
# Epoch 736 — Loss: 1.3291
# Epoch 737 — Loss: 1.2950
# Epoch 738 — Loss: 1.3164
# Epoch 739 — Loss: 1.2934
# Epoch 740 — Loss: 1.2801
# Epoch 741 — Loss: 1.2748
# Epoch 742 — Loss: 1.2814
# Epoch 743 — Loss: 1.2931
# Epoch 744 — Loss: 1.2811
# Epoch 745 — Loss: 1.3035
# Epoch 746 — Loss: 1.3678
# Epoch 747 — Loss: 1.3379
# Epoch 748 — Loss: 1.3087
# Epoch 749 — Loss: 1.2912
# Epoch 750 — Loss: 1.2724
# Epoch 751 — Loss: 1.2737
# Epoch 752 — Loss: 1.2677
# Epoch 753 — Loss: 1.3234
# Epoch 754 — Loss: 1.3745
# Epoch 755 — Loss: 1.3905
# Epoch 756 — Loss: 1.3312
# Epoch 757 — Loss: 1.2650
# Epoch 758 — Loss: 1.2423
# Epoch 759 — Loss: 1.2361
# Epoch 760 — Loss: 1.3020
# Epoch 761 — Loss: 1.3774
# Epoch 762 — Loss: 1.3219
# Epoch 763 — Loss: 1.3087
# Epoch 764 — Loss: 1.2772
# Epoch 765 — Loss: 1.3344
# Epoch 766 — Loss: 1.2924
# Epoch 767 — Loss: 1.3289
# Epoch 768 — Loss: 1.3602
# Epoch 769 — Loss: 1.4233
# Epoch 770 — Loss: 1.3627
# Epoch 771 — Loss: 1.2888
# Epoch 772 — Loss: 1.3234
# Epoch 773 — Loss: 1.7080
# Epoch 774 — Loss: 1.4942
# Epoch 775 — Loss: 1.3697
# Epoch 776 — Loss: 1.3972
# Epoch 777 — Loss: 1.3661
# Epoch 778 — Loss: 1.3960
# Epoch 779 — Loss: 1.3551
# Epoch 780 — Loss: 1.2651
# Epoch 781 — Loss: 1.2496
# Epoch 782 — Loss: 1.2496
# Epoch 783 — Loss: 1.2541
# Epoch 784 — Loss: 1.2756
# Epoch 785 — Loss: 1.3403
# Epoch 786 — Loss: 1.3030
# Epoch 787 — Loss: 1.3059
# Epoch 788 — Loss: 1.2753
# Epoch 789 — Loss: 1.2808
# Epoch 790 — Loss: 1.4445
# Epoch 791 — Loss: 1.4526
# Epoch 792 — Loss: 1.3359
# Epoch 793 — Loss: 1.3459
# Epoch 794 — Loss: 1.3025
# Epoch 795 — Loss: 1.2640
# Epoch 796 — Loss: 1.2577
# Epoch 797 — Loss: 1.2997
# Epoch 798 — Loss: 1.2986
# Epoch 799 — Loss: 1.3572
# Epoch 800 — Loss: 1.3658
# Epoch 801 — Loss: 1.3290
# Epoch 802 — Loss: 1.3454
# Epoch 803 — Loss: 1.2957
# Epoch 804 — Loss: 1.3370
# Epoch 805 — Loss: 1.3085
# Epoch 806 — Loss: 1.2629
# Epoch 807 — Loss: 1.2714
# Epoch 808 — Loss: 1.2543
# Epoch 809 — Loss: 1.2411
# Epoch 810 — Loss: 1.3023
# Epoch 811 — Loss: 1.3097
# Epoch 812 — Loss: 1.5383
# Epoch 813 — Loss: 1.6928
# Epoch 814 — Loss: 1.4471
# Epoch 815 — Loss: 1.4091
# Epoch 816 — Loss: 1.3155
# Epoch 817 — Loss: 1.3121
# Epoch 818 — Loss: 1.2685
# Epoch 819 — Loss: 1.2472
# Epoch 820 — Loss: 1.2505
# Epoch 821 — Loss: 1.2567
# Epoch 822 — Loss: 1.2774
# Epoch 823 — Loss: 1.2810
# Epoch 824 — Loss: 1.3624
# Epoch 825 — Loss: 1.3798
# Epoch 826 — Loss: 1.2857
# Epoch 827 — Loss: 1.2560
# Epoch 828 — Loss: 1.2477
# Epoch 829 — Loss: 1.2709
# Epoch 830 — Loss: 1.3259
# Epoch 831 — Loss: 1.3982
# Epoch 832 — Loss: 1.3171
# Epoch 833 — Loss: 1.3509
# Epoch 834 — Loss: 1.3435
# Epoch 835 — Loss: 1.3299
# Epoch 836 — Loss: 1.3652
# Epoch 837 — Loss: 1.3688
# Epoch 838 — Loss: 1.2979
# Epoch 839 — Loss: 1.2392
# Epoch 840 — Loss: 1.2530
# Epoch 841 — Loss: 1.4388
# Epoch 842 — Loss: 1.4214
# Epoch 843 — Loss: 1.4499
# Epoch 844 — Loss: 1.5140
# Epoch 845 — Loss: 1.4352
# Epoch 846 — Loss: 1.3741
# Epoch 847 — Loss: 1.3070
# Epoch 848 — Loss: 1.2623
# Epoch 849 — Loss: 1.2406
# Epoch 850 — Loss: 1.2453
# Epoch 851 — Loss: 1.2456
# Epoch 852 — Loss: 1.2420
# Epoch 853 — Loss: 1.2731
# Epoch 854 — Loss: 1.3516
# Epoch 855 — Loss: 1.3128
# Epoch 856 — Loss: 1.3599
# Epoch 857 — Loss: 1.3548
# Epoch 858 — Loss: 1.3252
# Epoch 859 — Loss: 1.3268
# Epoch 860 — Loss: 1.2824
# Epoch 861 — Loss: 1.2438
# Epoch 862 — Loss: 1.2431
# Epoch 863 — Loss: 1.2473
# Epoch 864 — Loss: 1.2855
# Epoch 865 — Loss: 1.3227
# Epoch 866 — Loss: 1.3030
# Epoch 867 — Loss: 1.3347
# Epoch 868 — Loss: 1.5808
# Epoch 869 — Loss: 1.4766
# Epoch 870 — Loss: 1.3122
# Epoch 871 — Loss: 1.3290
# Epoch 872 — Loss: 1.3293
# Epoch 873 — Loss: 1.2958
# Epoch 874 — Loss: 1.2502
# Epoch 875 — Loss: 1.2638
# Epoch 876 — Loss: 1.4329
# Epoch 877 — Loss: 1.4551
# Epoch 878 — Loss: 1.3514
# Epoch 879 — Loss: 1.2758
# Epoch 880 — Loss: 1.2999
# Epoch 881 — Loss: 1.3353
# Epoch 882 — Loss: 1.3274
# Epoch 883 — Loss: 1.3965
# Epoch 884 — Loss: 1.3891
# Epoch 885 — Loss: 1.3367
# Epoch 886 — Loss: 1.3151
# Epoch 887 — Loss: 1.2652
# Epoch 888 — Loss: 1.2330
# Epoch 889 — Loss: 1.2314
# Epoch 890 — Loss: 1.2898
# Epoch 891 — Loss: 1.3400
# Epoch 892 — Loss: 1.4629
# Epoch 893 — Loss: 1.3410
# Epoch 894 — Loss: 1.2834
# Epoch 895 — Loss: 1.2551
# Epoch 896 — Loss: 1.3563
# Epoch 897 — Loss: 1.3720
# Epoch 898 — Loss: 1.3105
# Epoch 899 — Loss: 1.3140
# Epoch 900 — Loss: 1.4396
# Epoch 901 — Loss: 1.3355
# Epoch 902 — Loss: 1.2858
# Epoch 903 — Loss: 1.2514
# Epoch 904 — Loss: 1.2449
# Epoch 905 — Loss: 1.2492
# Epoch 906 — Loss: 1.3405
# Epoch 907 — Loss: 1.5975
# Epoch 908 — Loss: 1.4102
# Epoch 909 — Loss: 1.2993
# Epoch 910 — Loss: 1.3023
# Epoch 911 — Loss: 1.2716
# Epoch 912 — Loss: 1.2795
# Epoch 913 — Loss: 1.3811
# Epoch 914 — Loss: 1.3035
# Epoch 915 — Loss: 1.2711
# Epoch 916 — Loss: 1.3056
# Epoch 917 — Loss: 1.3895
# Epoch 918 — Loss: 1.2930
# Epoch 919 — Loss: 1.2584
# Epoch 920 — Loss: 1.2873
# Epoch 921 — Loss: 1.3449
# Epoch 922 — Loss: 1.3910
# Epoch 923 — Loss: 1.3884
# Epoch 924 — Loss: 1.2953
# Epoch 925 — Loss: 1.2690
# Epoch 926 — Loss: 1.2546
# Epoch 927 — Loss: 1.2454
# Epoch 928 — Loss: 1.2286
# Epoch 929 — Loss: 1.3065
# Epoch 930 — Loss: 1.3485
# Epoch 931 — Loss: 1.3011
# Epoch 932 — Loss: 1.3297
# Epoch 933 — Loss: 1.3733
# Epoch 934 — Loss: 1.5784
# Epoch 935 — Loss: 1.4036
# Epoch 936 — Loss: 1.3602
# Epoch 937 — Loss: 1.3679
# Epoch 938 — Loss: 1.3167
# Epoch 939 — Loss: 1.3454
# Epoch 940 — Loss: 1.3158
# Epoch 941 — Loss: 1.2895
# Epoch 942 — Loss: 1.2644
# Epoch 943 — Loss: 1.3971
# Epoch 944 — Loss: 1.3795
# Epoch 945 — Loss: 1.3097
# Epoch 946 — Loss: 1.3561
# Epoch 947 — Loss: 1.3949
# Epoch 948 — Loss: 1.8157
# Epoch 949 — Loss: 1.5345
# Epoch 950 — Loss: 1.4634
# Epoch 951 — Loss: 1.3304
# Epoch 952 — Loss: 1.3450
# Epoch 953 — Loss: 1.2779
# Epoch 954 — Loss: 1.2628
# Epoch 955 — Loss: 1.2661
# Epoch 956 — Loss: 1.3173
# Epoch 957 — Loss: 1.3228
# Epoch 958 — Loss: 1.3023
# Epoch 959 — Loss: 1.2631
# Epoch 960 — Loss: 1.3682
# Epoch 961 — Loss: 1.3228
# Epoch 962 — Loss: 1.2771
# Epoch 963 — Loss: 1.2538
# Epoch 964 — Loss: 1.3090
# Epoch 965 — Loss: 1.3378
# Epoch 966 — Loss: 1.3266
# Epoch 967 — Loss: 1.5033
# Epoch 968 — Loss: 1.3652
# Epoch 969 — Loss: 1.3231
# Epoch 970 — Loss: 1.3024
# Epoch 971 — Loss: 1.2641
# Epoch 972 — Loss: 1.2587
# Epoch 973 — Loss: 1.2447
# Epoch 974 — Loss: 1.2763
# Epoch 975 — Loss: 1.2818
# Epoch 976 — Loss: 1.2490
# Epoch 977 — Loss: 1.2356
# Epoch 978 — Loss: 1.2347
# Epoch 979 — Loss: 1.2350
# Epoch 980 — Loss: 1.2393
# Epoch 981 — Loss: 1.2967
# Epoch 982 — Loss: 1.2854
# Epoch 983 — Loss: 1.2876
# Epoch 984 — Loss: 1.4242
# Epoch 985 — Loss: 1.3415
# Epoch 986 — Loss: 1.3490
# Epoch 987 — Loss: 1.3307
# Epoch 988 — Loss: 1.2811
# Epoch 989 — Loss: 1.2385
# Epoch 990 — Loss: 1.2492
# Epoch 991 — Loss: 1.2363
# Epoch 992 — Loss: 1.2398
# Epoch 993 — Loss: 1.2661
# Epoch 994 — Loss: 1.3756
# Epoch 995 — Loss: 1.2664
# Epoch 996 — Loss: 1.3121
# Epoch 997 — Loss: 1.5752
# Epoch 998 — Loss: 2.0582
# Epoch 999 — Loss: 2.0084

# %% [markdown]
# # Loading Pretrained model!

# %%
def load_trained_sae(path="../SAE_models/sae_enc0lin2.pth", input_dim=None, hidden_dim=128, sparsity_lambda=1e-4):
    sae = SparseAutoencoder(input_dim=input_dim, hidden_dim=hidden_dim, sparsity_lambda=sparsity_lambda).to(DEVICE)
    sae.load_state_dict(torch.load(path, map_location=DEVICE))
    sae.eval()
    return sae

sae = load_trained_sae(input_dim=feature_dim)
# Out:
# C:\Users\matis\AppData\Local\Temp\ipykernel_16056\4002313873.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   sae.load_state_dict(torch.load(path, map_location=DEVICE))

# %%
# load test batch

full_test_inputs = []
full_test_labels = []
for x, y in test_loader:
    full_test_inputs.append(x)
    full_test_labels.append(y)

test_batch = torch.cat(full_test_inputs).to(DEVICE)
test_labels = torch.cat(full_test_labels)

# %% [markdown]
# ## Extract Activations from Transformer (Test Set)

# %%
# cache activations on thest set
cache_test = run_and_cache(model, test_batch, targets=LAYER_TARGETS)
test_activations = list(cache_test.values())[0]  # (N, T, D)
test_activations = test_activations.view(-1, test_activations.size(-1)).cpu()

# reshape
total_timesteps, feat_dim = test_activations.shape
seq_len = test_batch.shape[1]
num_instances = total_timesteps // seq_len
assert num_instances * seq_len == total_timesteps, "Test timesteps not divisible by seq_len!"

test_raw_seqs = test_activations.view(num_instances, seq_len, feat_dim)  # (N, T, D)

# %% [markdown]
# ## Encode Test Set Activations with SAE

# %%
# compute SAE hidden activations
sae.eval()
with torch.no_grad():
    flat_test_raw      = test_raw_seqs.view(-1, feat_dim).to(DEVICE)  # (N*T, D)
    _, flat_test_hidden = sae(flat_test_raw)  # (N*T, H)
    test_hidden_seqs    = flat_test_hidden.view(num_instances, seq_len, -1)
    
    
idx = 44  # pick instance
raw_inst    = test_raw_seqs[idx].T.cpu().numpy()    # (D, T)
hidden_inst = test_hidden_seqs[idx].T.cpu().numpy() # (H, T)
true_label  = test_labels[idx].item()

# %% [markdown]
# ## Plot SAE vs Transformer Activations

# %%
# plot
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

im0 = axes[0].imshow(raw_inst, aspect='auto', cmap='Blues')
axes[0].set_title(f"Raw Transformer Activations (Test)")
axes[0].set_xlabel("Timestep")
axes[0].set_ylabel("Feature Dimension")
plt.colorbar(im0, ax=axes[0], fraction=0.046, pad=0.04)

im1 = axes[1].imshow(hidden_inst, aspect='auto', cmap='Blues')
axes[1].set_title(f"SAE Activations: Instance {idx} — True Label: {true_label}")
axes[1].set_xlabel("Timestep")
axes[1].set_ylabel("SAE Hidden Unit")
plt.colorbar(im1, ax=axes[1], fraction=0.046, pad=0.04)

fig.suptitle(f"Test Instance {idx} — True Label: {true_label}", fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# ## Prepare Test Arrays for Inspection

# %%
N, T, H = test_hidden_seqs.shape
test_hidden_np = test_hidden_seqs.cpu().numpy()  # (N, T, H)

test_inputs_np = test_batch.cpu().numpy()        # (N, T, C)
test_labels_np = test_labels.cpu().numpy()       # (N,)

# %% [markdown]
# ## Interactive Viewer for SAE Neuron Activity

# %%
def show_topk_for_neuron_timestep(neuron_idx=0, timestep=0):
    values = test_hidden_np[:, timestep, neuron_idx]  # shape (N,)
    
    topk = 5 # <- CHANGE HERE
    
    topk_indices = np.argsort(values)[-topk:][::-1]  # top k sorted descending
    topk_values  = values[topk_indices]

    print(f"Neuron {neuron_idx} @ Timestep {timestep} — Top-5 Activations")

    for rank, idx in enumerate(topk_indices):
        label = test_labels_np[idx]
        act_val = topk_values[rank]
        ts_input = test_inputs_np[idx]     # (T, C)
        hidden_inst = test_hidden_np[idx].T  # (H, T)

        fig, axes = plt.subplots(1, 2, figsize=(16, 5))

        time = np.arange(ts_input.shape[0])
        for ch in range(ts_input.shape[1]):
            axes[0].plot(time, ts_input[:, ch], label=f'Ch {ch}')
        axes[0].axvline(timestep, color='red', linestyle='--', label='Timestep')
        axes[0].set_title(f"[Rank {rank+1}] Raw Time Series — Instance {idx} (Label {label})")
        axes[0].set_xlabel("Timestep")
        axes[0].set_ylabel("Value")

        im1 = axes[1].imshow(hidden_inst, aspect='auto', interpolation='nearest', cmap='Blues')
        axes[1].axhline(neuron_idx, color='red', linestyle='-', label='Neuron', alpha=0.5)
        axes[1].axvline(timestep, color='red', linestyle='-', label='Timestep', alpha=0.5)
        axes[1].set_title(f"SAE Activations — Act[{neuron_idx},{timestep}] = {act_val:.3f}")
        axes[1].set_xlabel("Timestep")
        axes[1].set_ylabel("SAE Unit")
        plt.colorbar(im1, ax=axes[1], fraction=0.046, pad=0.04)

        # plt.suptitle(f"Top-{rank+1} Activation for Neuron {neuron_idx} @ Timestep {timestep}", fontsize=14)
        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        plt.show()

# %%
interact(
    show_topk_for_neuron_timestep,
    neuron_idx=IntSlider(min=0, max=127, step=1, value=0, description="Neuron"),
    timestep=IntSlider(min=0, max=test_batch.shape[1]-1, step=1, value=0, description="Timestep")
)
# Out:
# interactive(children=(IntSlider(value=0, description='Neuron', max=127), IntSlider(value=0, description='Times…
# <function __main__.show_topk_for_neuron_timestep(neuron_idx=0, timestep=0)>
